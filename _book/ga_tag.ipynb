# %%
ga_tag = open("ga_tag.txt", "r").read().strip()
ga_tag_lines = ga_tag.split("\n")
ga_tag_lines = [f"{line}\n" for line in ga_tag_lines]
ga_tag_lines[0] = "        " + ga_tag_lines[0]

# %%
from os import listdir
from os.path import isfile, join
path = "_book/contents"
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
onlyfiles = [f"{path}/{file}" for file in onlyfiles]
onlyfiles.append("_book/index.html")

# %%
n = len(" · HonKit</title>")
for file in onlyfiles:
    print(file)
    if not file.endswith("html"):
        print(file)
        continue
    correct_lines = []
    prev = None
    with open(file, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if prev == "<head>":
                correct_lines.extend(ga_tag_lines)
            if line.strip().endswith(" · HonKit</title>"):
                line = line[:-n-1] + " · MLIB</title>\n"
                correct_lines.append(line)
                break
            correct_lines.append(line)
            prev = line.strip()
        correct_lines.extend(lines[i + 1:])
    with open(file, "w") as f:
        text = "".join(correct_lines)
        f.write(text)
# Out:
# _book/contents/5.1.2-matrices.html
# _book/contents/2.3-types-of-questions.html
# _book/contents/5.1.1-vectors.html
# _book/contents/4.3.3-other-resources.html
# _book/contents/5.1-algebra-and-calculus.html
# _book/contents/6.1-algorithms.html
# _book/contents/8.1.1-overview:-basic-algorithm.html
# _book/contents/8.2.3-reinforcement-learning.html
# _book/contents/chapter-4.-where-to-start.html
# _book/contents/5.1.3-dimensionality-reduction.html
# _book/contents/3.1.1-base-salary.html
# _book/contents/4.3.1-courses.html
# _book/contents/part-i.-overview.html
# _book/contents/3.2.1-compensation-expectations.html
# _book/contents/1.1.3-production.html
# _book/contents/3.2-negotiation.html
# _book/contents/1.2.2-enterprise-vs.-consumer-products.html
# _book/contents/5.2.1-probability.html
# _book/contents/0-about-the-author.html
# _book/contents/1.1.2.2-research-scientist-vs.-research-engineer.html
# _book/contents/b.-building-your-network.html
# _book/contents/2.3.2-questions-to-ask-your-interviewers.html
# _book/contents/4.3.2-books-&-articles.html
# _book/contents/8.2.1-natural-language-processing.html
# _book/contents/2.1-understanding-the-interviewers’-mindset.html
# _book/contents/2.1.2-how-companies-source-candidates.html
# _book/contents/1.1.1-working-in-research-vs.-workingin-production.html
# _book/contents/1.2.1-applications-companies-vs.-tooling-companies.html
# _book/contents/4.4-do’s-and-don’ts-for-ml-interviews.html
# _book/contents/a.-for-interviewers.html
# _book/contents/chapter-6.-computer-science.html
# _book/contents/5.2.1.2-questions.html
# _book/contents/2.1.1.3-what-exactly-is-culture-fit.html
# _book/contents/chapter-1.-ml-jobs.html
# _book/contents/2.6-understanding-your-odds.html
# _book/contents/0-gaming-the-interview-process.html
# _book/contents/0-about-the-questions.html
# _book/contents/8.3-training-neural-networks.html
# _book/contents/2.1.1.5-do-i-need-a-ph.d.-to-work-in-machine-learning.html
# _book/contents/4.2-how-other-people-did-it.html
# _book/contents/chapter-3.-after-an-offer.html
# _book/contents/2.3.3-bad-interview-questions.html
# _book/contents/2.2.2-alternative-interview-formats.html
# _book/contents/2.1.1-what-companies-want-from-candidates.html
# _book/contents/1.1.3.3-machine-learning-engineer-vs.-data-scientist.html
# _book/contents/1.1.2-research.html
# _book/contents/2.2.1-common-interview-formats.html
# _book/contents/1.1.3.4-other-technical-roles-in-ml-production.html
# _book/contents/2.1.1.2-non-technical-skills.html
# _book/contents/chapter-2.-machine-learning-interview-process.html
# _book/contents/0-target-audience.html
# _book/contents/appendix.html
# _book/contents/2.3.1.1-background-and-resume.html
# _book/contents/3.1.3-bonuses.html
# _book/contents/2.1.1.1-technical-skills.html
# _book/contents/4.4.1-do’s.html
# _book/contents/2.2-interview-pipeline.html
# _book/contents/8.2.2-computer-vision.html
# _book/contents/1.2.3-startups-or-big-companies.html
# _book/contents/2.2.3-interviews-at-big-companies-vs.-at-small-companies.html
# _book/contents/2.3.1.4-personality.html
# _book/contents/chapter-5.-math.html
# _book/contents/6.3-data.html
# _book/contents/1.1.3.2-machine-learning-engineer-vs.-software-engineer.html
# _book/contents/8.1-classical-machine-learning.html
# _book/contents/8.2-deep-learning-architectures-and-applications.html
# _book/contents/2.3.1.3-communication.html
# _book/contents/0-about-the-answers.html
# _book/contents/chapter-8.-machine-learning-algorithms.html
# _book/contents/5.2-probability-and-statistics.html
# _book/contents/0-acknowledgments.html
# _book/contents/7.3-objective-functions,-metrics,-and-evaluation.html
# _book/contents/3.1.4-compensation-packages-at-different-levels.html
# _book/contents/2.3.1.2-interests.html
# _book/contents/4.4.2-don’ts.html
# _book/contents/5.1.4-calculus-and-convex-optimization.html
# _book/contents/1.1.3.1-production-cycle.html
# _book/contents/5.2.2-stats.html
# _book/contents/1.1.3.5-understanding-roles-and-titles.html
# _book/contents/2.2.4-interviews-for-internships-vs.-for-full-time-positions.html
# _book/contents/2.1.1.4-junior-vs-senior-roles.html
# _book/contents/2.3.1-behavioral-questions.html
# _book/contents/1.2-types-of-companies.html
# _book/contents/1.1.2.1-research-vs.-applied-research.html
# _book/contents/1.1-different-ml-roles.html
# _book/contents/4.1-how-long-do-i-need-for-my-job-search.html
# _book/contents/2.1.3-what-signals-companies-look-for-in-candidates.html
# _book/contents/the-zen-of-interviews.html
# _book/contents/part-ii.-questions.html
# _book/contents/chapter-7.-machine-learning-workflows.html
# _book/contents/4.3-resources.html
# _book/contents/3.3-career-progression.html
# _book/contents/8.1.2-questions.html
# _book/contents/7.2-sampling-and-creating-training-data.html
# _book/contents/8.2.4-other.html
# _book/contents/3.1.2-equity-grants.html
# _book/contents/6.3.1-data-structures.html
# _book/contents/6.2-complexity-and-numerical-analysis.html
# _book/contents/2.4-red-flags.html
# _book/contents/notation.html
# _book/contents/3.1-compensation-package.html
# _book/contents/7.1-basics.html
# _book/contents/2.5-timeline.html
# _book/contents/5.2.1.1-basic-concepts-to-review.html
# _book/index.html

# %% [markdown]
# ```
# git checkout html
# rm -rf *
# git checkout master -- _book
# mv _book/* .
# rm -rf _book
# git add -A && git commit -am "Update html file" && git push
# ```

# %%
(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');

ga('create', 'UA-103070243-5', 'auto');
ga('send', 'pageview');
